# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import os
import seaborn as sns

# %%
os.chdir("D:\\study\\Gmu\\sem2\\Ait-664\\Final Proj")

# %% [markdown]
# ### Loading the data sets

# %%
data1 = pd.read_csv("police_shootings.csv")
data1.head()
# Out:
#           Person.Name  Person.Age Person.Gender Person.Race  \
# 0          Tim Elliot          53          Male       Asian
# 1    Lewis Lee Lembke          47          Male       White
# 2  John Paul Quintero          23          Male    Hispanic
# 3     Matthew Hoffman          32          Male       White
# 4   Michael Rodriguez          39          Male    Hispanic
#
#    Incident.Date.Month  Incident.Date.Day  Incident.Date.Year  \
# 0                    1                  2                2015
# 1                    1                  2                2015
# 2                    1                  3                2015
# 3                    1                  4                2015
# 4                    1                  4                2015
#
#   Incident.Date.Full Incident.Location.City Incident.Location.State  \
# 0         2015/01/02                Shelton                      WA
# 1         2015/01/02                  Aloha                      OR
# ...

# %%
data2 = pd.read_csv("state_crime.csv")
data2.head()
# Out:
#      State  Year  Data.Population  Data.Rates.Property.All  \
# 0  Alabama  1960          3266740                   1035.4
# 1  Alabama  1961          3302000                    985.5
# 2  Alabama  1962          3358000                   1067.0
# 3  Alabama  1963          3347000                   1150.9
# 4  Alabama  1964          3407000                   1358.7
#
#    Data.Rates.Property.Burglary  Data.Rates.Property.Larceny  \
# 0                         355.9                        592.1
# 1                         339.3                        569.4
# 2                         349.1                        634.5
# 3                         376.9                        683.4
# 4                         466.6                        784.1
#
#    Data.Rates.Property.Motor  Data.Rates.Violent.All  \
# 0                       87.3                   186.6
# 1                       76.8                   168.5
# 2                       83.4                   157.3
# ...

# %%
data3 = pd.read_csv("HT.csv")
data3.head()
# Out:
#    DATA_YEAR        ORI                           PUB_AGENCY_NAME  \
# 0       2016  MO0480600                              Independence
# 1       2016  TX2201200                                Fort Worth
# 2       2016  TX2270100                                    Austin
# 3       2019  NV0020100  Las Vegas Metropolitan Police Department
# 4       2017  AZ0070500                                  Chandler
#
#   PUB_AGENCY_UNIT AGENCY_TYPE_NAME STATE_ABBR STATE_NAME       DIVISION_NAME  \
# 0             NaN             City         MO   Missouri  West North Central
# 1             NaN             City         TX      Texas  West South Central
# 2             NaN             City         TX      Texas  West South Central
# 3             NaN             City         NV     Nevada            Mountain
# 4             NaN             City         AZ    Arizona            Mountain
#
#                COUNTY_NAME REGION_NAME POPULATION_GROUP_CODE  \
# ...

# %% [markdown]
# ### Removing Unwanted Columns

# %%
list(data3.columns)
# Out:
# ['DATA_YEAR',
#  'ORI',
#  'PUB_AGENCY_NAME',
#  'PUB_AGENCY_UNIT',
#  'AGENCY_TYPE_NAME',
#  'STATE_ABBR',
#  'STATE_NAME',
#  'DIVISION_NAME',
#  'COUNTY_NAME',
#  'REGION_NAME',
#  'POPULATION_GROUP_CODE',
#  'POPULATION_GROUP_DESC',
#  'OFFENSE_SUBCAT_ID',
#  'OFFENSE_NAME',
#  'OFFENSE_SUBCAT_NAME',
#  'ACTUAL_COUNT',
#  'UNFOUNDED_COUNT',
#  'CLEARED_COUNT',
#  'JUVENILE_CLEARED_COUNT']

# %%
ht=data3.drop(labels=['ORI','PUB_AGENCY_NAME',
 'PUB_AGENCY_UNIT',
 'AGENCY_TYPE_NAME','DIVISION_NAME',
 'COUNTY_NAME','POPULATION_GROUP_CODE',
 'POPULATION_GROUP_DESC',
 'OFFENSE_SUBCAT_ID',
 'OFFENSE_NAME'],axis=1)
list(ht.columns)
# Out:
# ['DATA_YEAR',
#  'STATE_ABBR',
#  'STATE_NAME',
#  'REGION_NAME',
#  'OFFENSE_SUBCAT_NAME',
#  'ACTUAL_COUNT',
#  'UNFOUNDED_COUNT',
#  'CLEARED_COUNT',
#  'JUVENILE_CLEARED_COUNT']

# %%
list(data2.columns)
# Out:
# ['State',
#  'Year',
#  'Data.Population',
#  'Data.Rates.Property.All',
#  'Data.Rates.Property.Burglary',
#  'Data.Rates.Property.Larceny',
#  'Data.Rates.Property.Motor',
#  'Data.Rates.Violent.All',
#  'Data.Rates.Violent.Assault',
#  'Data.Rates.Violent.Murder',
#  'Data.Rates.Violent.Rape',
#  'Data.Rates.Violent.Robbery',
#  'Data.Totals.Property.All',
#  'Data.Totals.Property.Burglary',
#  'Data.Totals.Property.Larceny',
#  'Data.Totals.Property.Motor',
#  'Data.Totals.Violent.All',
#  'Data.Totals.Violent.Assault',
#  'Data.Totals.Violent.Murder',
#  'Data.Totals.Violent.Rape',
#  'Data.Totals.Violent.Robbery']

# %%
list(data1.columns)
# Out:
# ['Person.Name',
#  'Person.Age',
#  'Person.Gender',
#  'Person.Race',
#  'Incident.Date.Month',
#  'Incident.Date.Day',
#  'Incident.Date.Year',
#  'Incident.Date.Full',
#  'Incident.Location.City',
#  'Incident.Location.State',
#  'Factors.Armed',
#  'Factors.Mental-Illness',
#  'Factors.Threat-Level',
#  'Factors.Fleeing',
#  'Shooting.Manner',
#  'Shooting.Body-Camera']

# %%
ps=data1.drop(labels=['Person.Name','Incident.Date.Full','Factors.Mental-Illness','Shooting.Body-Camera'],axis=1)
list(ps.columns)
ps.dropna()
# Out:
#       Person.Age Person.Gender Person.Race  Incident.Date.Month  \
# 0             53          Male       Asian                    1
# 1             47          Male       White                    1
# 2             23          Male    Hispanic                    1
# 3             32          Male       White                    1
# 4             39          Male    Hispanic                    1
# ...          ...           ...         ...                  ...
# 4289          17          Male     Unknown                    5
# 4290           0          Male     Unknown                    5
# 4291          34        Female     Unknown                    5
# 4292          46          Male     Unknown                    5
# 4293           0          Male     Unknown                    5
#
#       Incident.Date.Day  Incident.Date.Year Incident.Location.City  \
# 0                     2                2015                Shelton
# ...

# %%
sc=data2[data2['Year']>=2015]
sc.head()
sc.dropna()
# Out:
#         State  Year  Data.Population  Data.Rates.Property.All  \
# 55    Alabama  2015          4858979                    328.3
# 56    Alabama  2016          4863300                   2947.8
# 57    Alabama  2017          4874747                   2957.3
# 58    Alabama  2018          4887871                   2817.2
# 59    Alabama  2019          4903185                   2674.4
# ...       ...   ...              ...                      ...
# 3110  Wyoming  2015           586107                    179.8
# 3111  Wyoming  2016           585501                   1957.3
# 3112  Wyoming  2017           579315                   1830.4
# 3113  Wyoming  2018           577737                   1785.1
# 3114  Wyoming  2019           578759                   1571.1
#
#       Data.Rates.Property.Burglary  Data.Rates.Property.Larceny  \
# 55                          2978.9                        725.6
# 56                           700.5                       2006.3
# ...

# %%
ht=ht[ht['DATA_YEAR']>=2015]
ht.count()
# Out:
# DATA_YEAR                 4160
# STATE_ABBR                4160
# STATE_NAME                4160
# REGION_NAME               4160
# OFFENSE_SUBCAT_NAME       4160
# ACTUAL_COUNT              4160
# UNFOUNDED_COUNT           4160
# CLEARED_COUNT             4160
# JUVENILE_CLEARED_COUNT    4160
# dtype: int64

# %%
ht.dropna()
# Out:
#       DATA_YEAR STATE_ABBR STATE_NAME REGION_NAME    OFFENSE_SUBCAT_NAME  \
# 0          2016         MO   Missouri     Midwest    Commercial Sex Acts
# 1          2016         TX      Texas       South  Involuntary Servitude
# 2          2016         TX      Texas       South  Involuntary Servitude
# 3          2019         NV     Nevada        West    Commercial Sex Acts
# 4          2017         AZ    Arizona        West    Commercial Sex Acts
# ...         ...        ...        ...         ...                    ...
# 4412       2019         KY   Kentucky       South  Involuntary Servitude
# 4413       2019         KY   Kentucky       South  Involuntary Servitude
# 4414       2020         KY   Kentucky       South    Commercial Sex Acts
# 4415       2020         KY   Kentucky       South    Commercial Sex Acts
# 4416       2020         KY   Kentucky       South    Commercial Sex Acts
#
#       ACTUAL_COUNT  UNFOUNDED_COUNT  CLEARED_COUNT  JUVENILE_CLEARED_COUNT
# ...

# %%
ht.rename(columns={'DATA_YEAR':'Year','STATE_ABBR':'State'},inplace=True)
ht.head()
# Out:
#    Year State STATE_NAME REGION_NAME    OFFENSE_SUBCAT_NAME  ACTUAL_COUNT  \
# 0  2016    MO   Missouri     Midwest    Commercial Sex Acts             2
# 1  2016    TX      Texas       South  Involuntary Servitude             1
# 2  2016    TX      Texas       South  Involuntary Servitude             2
# 3  2019    NV     Nevada        West    Commercial Sex Acts            15
# 4  2017    AZ    Arizona        West    Commercial Sex Acts             1
#
#    UNFOUNDED_COUNT  CLEARED_COUNT  JUVENILE_CLEARED_COUNT
# 0                0              2                       0
# 1                0              0                       0
# 2                0              0                       0
# 3                0              4                       0
# 4                0              0                       0

# %%
ps.rename(columns={'Incident.Location.State':'State','Incident.Date.Year':'Year',},inplace=True)
ps.count()
# Out:
# Person.Age                4294
# Person.Gender             4294
# Person.Race               4294
# Incident.Date.Month       4294
# Incident.Date.Day         4294
# Year                      4294
# Incident.Location.City    4294
# State                     4294
# Factors.Armed             4294
# Factors.Threat-Level      4294
# Factors.Fleeing           4294
# Shooting.Manner           4294
# dtype: int64

# %%
p_crimes= sc[['State',
 'Year','Data.Population',
 'Data.Rates.Property.All',
 'Data.Rates.Property.Burglary',
 'Data.Rates.Property.Larceny',
 'Data.Rates.Property.Motor','Data.Totals.Property.All',
 'Data.Totals.Property.Burglary',
 'Data.Totals.Property.Larceny',
 'Data.Totals.Property.Motor']]

p_crimes.head()
# Out:
#       State  Year  Data.Population  Data.Rates.Property.All  \
# 55  Alabama  2015          4858979                    328.3
# 56  Alabama  2016          4863300                   2947.8
# 57  Alabama  2017          4874747                   2957.3
# 58  Alabama  2018          4887871                   2817.2
# 59  Alabama  2019          4903185                   2674.4
#
#     Data.Rates.Property.Burglary  Data.Rates.Property.Larceny  \
# 55                        2978.9                        725.6
# 56                         700.5                       2006.3
# 57                         645.7                       2048.1
# 58                         590.1                       1958.9
# 59                         531.9                       1886.1
#
#     Data.Rates.Property.Motor  Data.Totals.Property.All  \
# 55                     2040.7                     15954
# 56                      241.1                    143362
# ...

# %%
v_crime=sc[['State',
 'Year','Data.Population',
'Data.Rates.Violent.All',
 'Data.Rates.Violent.Assault',
 'Data.Rates.Violent.Murder',
 'Data.Rates.Violent.Rape',
 'Data.Rates.Violent.Robbery','Data.Totals.Violent.All',
 'Data.Totals.Violent.Assault',
 'Data.Totals.Violent.Murder',
 'Data.Totals.Violent.Rape',
 'Data.Totals.Violent.Robbery']]

v_crime.head()
# Out:
#       State  Year  Data.Population  Data.Rates.Violent.All  \
# 55  Alabama  2015          4858979                   472.4
# 56  Alabama  2016          4863300                   532.3
# 57  Alabama  2017          4874747                   524.2
# 58  Alabama  2018          4887871                   519.6
# 59  Alabama  2019          4903185                   510.8
#
#     Data.Rates.Violent.Assault  Data.Rates.Violent.Murder  \
# 55                        94.9                        7.2
# 56                       388.2                        8.4
# 57                       387.8                        8.3
# 58                       387.6                        7.8
# 59                       381.0                        7.3
#
#     Data.Rates.Violent.Rape  Data.Rates.Violent.Robbery  \
# 55                     42.0                        30.0
# 56                     39.4                        96.4
# 57                     41.6                        86.5
# ...

# %%
sc.head()
# Out:
#       State  Year  Data.Population  Data.Rates.Property.All  \
# 55  Alabama  2015          4858979                    328.3
# 56  Alabama  2016          4863300                   2947.8
# 57  Alabama  2017          4874747                   2957.3
# 58  Alabama  2018          4887871                   2817.2
# 59  Alabama  2019          4903185                   2674.4
#
#     Data.Rates.Property.Burglary  Data.Rates.Property.Larceny  \
# 55                        2978.9                        725.6
# 56                         700.5                       2006.3
# 57                         645.7                       2048.1
# 58                         590.1                       1958.9
# 59                         531.9                       1886.1
#
#     Data.Rates.Property.Motor  Data.Rates.Violent.All  \
# 55                     2040.7                   472.4
# 56                      241.1                   532.3
# 57                      263.4                   524.2
# ...

# %%
sc.rename(columns={'State':'State_Name'},inplace=True)

# %%
inc_happ=1

# %%
ps['ps_happ']=inc_happ
ps.head()
# Out:
#    Person.Age Person.Gender Person.Race  Incident.Date.Month  \
# 0          53          Male       Asian                    1
# 1          47          Male       White                    1
# 2          23          Male    Hispanic                    1
# 3          32          Male       White                    1
# 4          39          Male    Hispanic                    1
#
#    Incident.Date.Day  Year Incident.Location.City State Factors.Armed  \
# 0                  2  2015                Shelton    WA           gun
# 1                  2  2015                  Aloha    OR           gun
# 2                  3  2015                Wichita    KS       unarmed
# 3                  4  2015          San Francisco    CA    toy weapon
# 4                  4  2015                  Evans    CO      nail gun
#
#   Factors.Threat-Level Factors.Fleeing   Shooting.Manner  ps_happ
# 0               attack     Not fleeing              shot        1
# ...

# %%
p_crimes.corr()['Data.Rates.Property.All']
# Out:
# Year                             0.488456
# Data.Population                 -0.008997
# Data.Rates.Property.All          1.000000
# Data.Rates.Property.Burglary    -0.683198
# Data.Rates.Property.Larceny      0.974456
# Data.Rates.Property.Motor       -0.687850
# Data.Totals.Property.All         0.096324
# Data.Totals.Property.Burglary   -0.155709
# Data.Totals.Property.Larceny     0.074168
# Data.Totals.Property.Motor      -0.165591
# Name: Data.Rates.Property.All, dtype: float64

# %%
v_crime.corr()['Data.Totals.Violent.All']
# Out:
# Year                          -0.000326
# Data.Population                0.999028
# Data.Rates.Violent.All         0.028740
# Data.Rates.Violent.Assault     0.017660
# Data.Rates.Violent.Murder      0.017395
# Data.Rates.Violent.Rape       -0.058443
# Data.Rates.Violent.Robbery     0.061060
# Data.Totals.Violent.All        1.000000
# Data.Totals.Violent.Assault    0.965402
# Data.Totals.Violent.Murder     0.998220
# Data.Totals.Violent.Rape       0.997448
# Data.Totals.Violent.Robbery    0.946243
# Name: Data.Totals.Violent.All, dtype: float64

# %%
sc.corr()[['Year']]
# Out:
#                                    Year
# Year                           1.000000
# Data.Population                0.002168
# Data.Rates.Property.All        0.488456
# Data.Rates.Property.Burglary  -0.693342
# Data.Rates.Property.Larceny    0.438828
# Data.Rates.Property.Motor     -0.668491
# Data.Rates.Violent.All        -0.014675
# Data.Rates.Violent.Assault     0.358842
# Data.Rates.Violent.Murder      0.002038
# Data.Rates.Violent.Rape        0.084813
# Data.Rates.Violent.Robbery     0.143221
# Data.Totals.Property.All       0.068854
# Data.Totals.Property.Burglary -0.145550
# Data.Totals.Property.Larceny   0.053920
# Data.Totals.Property.Motor    -0.147456
# Data.Totals.Violent.All       -0.000326
# Data.Totals.Violent.Assault    0.053225
# Data.Totals.Violent.Murder     0.001015
# Data.Totals.Violent.Rape       0.011995
# Data.Totals.Violent.Robbery    0.044036

# %%
ps.corr()[['Year']]
# Out:
#                          Year
# Person.Age          -0.049331
# Incident.Date.Month -0.197640
# Incident.Date.Day   -0.049425
# Year                 1.000000
# ps_happ                   NaN

# %% [markdown]
# ## Saving Modified Files

# %%
p_crimes.to_csv('AIT664_Final_Project_Data1.csv')

# %%
v_crime.to_csv('AIT664_Final_Project_Data2.csv')

# %%
ps.to_csv('AIT664_Final_Project_Data3.csv')

# %%
ht.to_csv('AIT664_Final_Project_Data4.csv')
