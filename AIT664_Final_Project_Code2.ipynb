# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import os
import seaborn as sns

# %%
os.chdir("D:\\study\\Gmu\\sem2\\Ait-664\\Final Proj")

# %%
data = pd.read_csv("ps.csv")
data.head()
# Out:
#    Unnamed: 0  Person.Age Person.Gender Person.Race  Incident.Date.Month  \
# 0           0          53          Male       Asian                    1
# 1           1          47          Male       White                    1
# 2           2          23          Male    Hispanic                    1
# 3           3          32          Male       White                    1
# 4           4          39          Male    Hispanic                    1
#
#    Incident.Date.Day  Year Incident.Location.City State Factors.Armed  \
# 0                  2  2015                Shelton    WA           gun
# 1                  2  2015                  Aloha    OR           gun
# 2                  3  2015                Wichita    KS       unarmed
# 3                  4  2015          San Francisco    CA    toy weapon
# 4                  4  2015                  Evans    CO      nail gun
#
#   Factors.Threat-Level Factors.Fleeing   Shooting.Manner  ps_happ
# ...

# %%
print("Dataset has",data.shape[0],"rows and",data.shape[1], "columns")
# Out:
# Dataset has 4294 rows and 14 columns

# %%
#number of shootings per year
year_data = data['Year'].value_counts()
year_data
# Out:
# 2015    994
# 2018    992
# 2017    986
# 2016    962
# 2019    360
# Name: Year, dtype: int64

# %%
year_data.plot(kind="bar", xlabel="Year", ylabel="Count", title="shootings per Year", figsize=(6,6))
# Out:
# <AxesSubplot:title={'center':'shootings per Year'}, xlabel='Year', ylabel='Count'>

# %% [markdown]
# #### Generic

# %% [markdown]
# # Attacking style

# %%
g_d=data['Factors.Armed'].value_counts()

# %%
g_d.plot(kind="line", xlabel="Types of Arms", ylabel="Count", title="Weapons Used", figsize=(12,6), color='green', grid="bool",linestyle="dashed",linewidth=3)
# Out:
# <AxesSubplot:title={'center':'Weapons Used'}, xlabel='Types of Arms', ylabel='Count'>

# %%
f_d=data['Factors.Fleeing'].value_counts()  
f_d
# Out:
# Not fleeing    2755
# Car             697
# Foot            546
# unknown         163
# Other           133
# Name: Factors.Fleeing, dtype: int64

# %%
# defining labels
activities = ['Not Fleeing', 'Car', 'Foot', 'Unknown','other']
 
# portion covered by each label
slices = [3, 7, 8, 6]
 
# color for each label
colors = ['r', 'y', 'g', 'b','y']

plt.pie(f_d, labels = activities, colors=colors,
        startangle=90, shadow = True, explode = (0.09, 0.01, 0.3, 0,0.1),
        radius = 2.4, autopct = '%1.1f%%')
plt.title("Fleeing", x=0.5, y=1.7)
# Out:
# Text(0.5, 1.7, 'Fleeing')

# %% [markdown]
# ## Threat_Levels

# %%
t_d=data['Factors.Threat-Level'].value_counts()

# %%
t_d.plot(kind="bar", xlabel="ThreatLevel", ylabel="Count", title="ThreatLevel", figsize=(12,6), color='brown', grid="bool")
# Out:
# <AxesSubplot:title={'center':'ThreatLevel'}, xlabel='ThreatLevel', ylabel='Count'>

# %%
m_d=data['Shooting.Manner'].value_counts()

# %%
m_d.plot(kind="bar", xlabel="Shooting Manner", ylabel="Count", title="Shooting Manner", figsize=(12,6), grid="bool",color="purple")
# Out:
# <AxesSubplot:title={'center':'Shooting Manner'}, xlabel='Shooting Manner', ylabel='Count'>

# %% [markdown]
# # Month wise

# %%
m_d=data['Incident.Date.Month'].value_counts()

# %%
m_d.plot(kind="bar", xlabel="Shooting Manner", ylabel="Count", title="Shooting Manner", figsize=(12,6), grid="bool")
# Out:
# <AxesSubplot:title={'center':'Shooting Manner'}, xlabel='Shooting Manner', ylabel='Count'>

# %% [markdown]
# # Race & Age

# %%
r_d=data['Person.Race'].value_counts()

# %%
r_d.plot(kind="area", xlabel="Year", ylabel="Count", title="shootings based on Race", color='purple', grid="bool")
plt.xticks(rotation = 45)
# Out:
# (array([-1.,  0.,  1.,  2.,  3.,  4.,  5.,  6.,  7.]),
#  [Text(-1.0, 0, 'Other'),
#   Text(0.0, 0, 'White'),
#   Text(1.0, 0, 'African American'),
#   Text(2.0, 0, 'Hispanic'),
#   Text(3.0, 0, 'Unknown'),
#   Text(4.0, 0, 'Asian'),
#   Text(5.0, 0, 'Native American'),
#   Text(6.0, 0, 'Other'),
#   Text(7.0, 0, '')])

# %% [markdown]
# ### Age

# %%
age_d=data['Person.Age'].value_counts()

# %%
age_d.plot(kind="bar", xlabel="Year", ylabel="Count", title="shootings based on Age", figsize=(16,6), color='teal', grid="bool")
# Out:
# <AxesSubplot:title={'center':'shootings based on Age'}, xlabel='Year', ylabel='Count'>

# %%
g_d=data['Person.Gender'].value_counts()

# %%
# library
import matplotlib.pyplot as plt

names = ['Male', 'Female', 'Unkown']
# Create a pieplot
plt.pie(g_d,labels=names,autopct = '%1.1f%%')

# add a circle at the center to transform it in a donut chart
my_circle=plt.Circle( (0,0), 0.7, color='white')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title("Gender Wise Analysis")

plt.show()

# %% [markdown]
# ### State

# %%
s_d=data['State'].value_counts()

# %%
s_d.plot(kind="bar", xlabel="Year", ylabel="Count",  figsize=(16,6), color='purple', grid="bool")
plt.xticks(rotation = 45)
plt.title("shootings per State")
# Out:
# Text(0.5, 1.0, 'shootings per State')

# %% [markdown]
# <h1><center> Year Wise Analysis</center></h1>

# %% [markdown]
# ### Subsetting Data

# %%
d_2015 = data[data["Year"] == 2015]

# %%
d_2016 = data[data["Year"] == 2016]

# %%
d_2017 = data[data["Year"] == 2017]

# %%
d_2018 = data[data["Year"] == 2018]

# %%
d_2019 = data[data["Year"] == 2019]

# %% [markdown]
# ## Attacking Style

# %% [markdown]
# #### Types of Weapons Used

# %%
attacks_data_2015=d_2015['Factors.Armed'].value_counts()

# %%
arms_15=attacks_data_2015.plot(kind="line", xlabel="Types of Arms", ylabel="Count", title="Types of Weapons used in 2015",linewidth=3, linestyle='dashed',grid="bool")
plt.xticks(rotation = 45)
plt.title("Types of Weapons used in 2015")
# Out:
# Text(0.5, 1.0, 'Types of Weapons used in 2015')

# %%
attacks_data_2016=d_2016['Factors.Armed'].value_counts()

# %%
arms_16=attacks_data_2016.plot(kind="line", xlabel="Types of Arms", ylabel="Count",linewidth=3, linestyle='dashed',grid="bool",color='purple')
plt.xticks(rotation = 45)
plt.title("Types of Weapons used in 2016")
# Out:
# Text(0.5, 1.0, 'Types of Weapons used in 2016')

# %%
attacks_data_2017=d_2017['Factors.Armed'].value_counts()

# %%
arms_17=attacks_data_2017.plot(kind="line", xlabel="Types of Arms", ylabel="Count", title="Types of weapons used in 2017",linewidth=3,color='purple', grid="bool",linestyle='dashed')
plt.xticks(rotation = 45)
plt.title("Types of Weapons used in 2017")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-3c020d331c70> in <module>
# ----> 1 arms_17=attacks_data_2017.plot(kind="line", xlabel="Types of Arms", ylabel="Count", title="Types of weapons used in 2017",linewidth=3,color='purple', grid="bool",linestyle='dashed')
#       2 plt.xticks(rotation = 45)
#       3 plt.title("Types of Weapons used in 2017")
#
# NameError: name 'attacks_data_2017' is not defined

# %%
attacks_data_2018=d_2018['Factors.Armed'].value_counts()

# %%
arms_18=attacks_data_2018.plot(kind="line", xlabel="Types of Arms", ylabel="Count", title="Types of weapons used in 2018", color='purple', grid="bool",linestyle='dashed',linewidth=3)
plt.xticks(rotation = 45)
plt.title("Types of Weapons used in 2018")
# Out:
# Text(0.5, 1.0, 'Types of Weapons used in 2018')

# %%
attacks_data_2019=d_2019['Factors.Armed'].value_counts()

# %%
arms_19=attacks_data_2019.plot(kind="line", xlabel="Types of Arms", ylabel="Count", title="Types of Weapons Used in 2019",linewidth=3,color='purple', grid="bool",linestyle='dashed')
plt.xticks(rotation = 45)
plt.title("Types of Weapons used in 2019")
# Out:
# Text(0.5, 1.0, 'Types of Weapons used in 2019')

# %% [markdown]
# ### Fleeing

# %%
f_d_15=d_2015['Factors.Fleeing'].value_counts()

# %%
plt.pie(f_d_15, labels = activities, colors=colors,
        startangle=90, shadow = True, explode = (0.09, 0.01, 0.3, 0,0.1),
        radius = 2.4, autopct = '%1.1f%%')
plt.title("Fleeing for 2015", x=0.5, y=1.7)
# Out:
# Text(0.5, 1.7, 'Fleeing for 2015')

# %%
f_d_16=d_2016['Factors.Fleeing'].value_counts()

# %%
plt.pie(f_d_16, labels = activities, colors=colors,
        startangle=90, shadow = True, explode = (0.09, 0.01, 0.3, 0,0.1),
        radius = 2.4, autopct = '%1.1f%%')
plt.title("Fleeing for 2016", x=0.5, y=1.7)
# Out:
# Text(0.5, 1.7, 'Fleeing for 2016')

# %%
f_d_17=d_2017['Factors.Fleeing'].value_counts()

# %%
plt.pie(f_d_17, labels = activities, colors=colors,
        startangle=90, shadow = True, explode = (0.09, 0.01, 0.3, 0,0.1),
        radius = 2.4, autopct = '%1.1f%%')
plt.title("Fleeing for 2017",x=0.5, y=1.7)
# Out:
# Text(0.5, 1.7, 'Fleeing for 2017')

# %%
f_d_18=d_2018['Factors.Fleeing'].value_counts()

# %%
plt.pie(f_d_18, labels = activities, colors=colors,
        startangle=90, shadow = True, explode = (0.09, 0.01, 0.3, 0,0.1),
        radius = 2.4, autopct = '%1.1f%%')
plt.title("Fleeing for 2018",x=0.5, y=1.7)
# Out:
# Text(0.5, 1.7, 'Fleeing for 2018')

# %%
f_d_19=d_2019['Factors.Fleeing'].value_counts()

# %%
plt.pie(f_d_19, labels = activities, colors=colors,
        startangle=90, shadow = True, explode = (0.09, 0.01, 0.3, 0,0.1),
        radius = 2.4, autopct = '%1.1f%%')
plt.title("Fleeing for 2019",x=0.5, y=1.7)
# Out:
# Text(0.5, 1.7, 'Fleeing for 2019')

# %% [markdown]
# ## Race & Age

# %% [markdown]
# ###### Age

# %%
r_d_2015=d_2015['Person.Race'].value_counts()

# %%
r_d_2015.plot(kind="area", xlabel="Year", ylabel="Count", title="shootings for 2015 based on Race", figsize=(6,6), color='cyan', grid="bool")
plt.xticks(rotation = 45)
plt.title("shootings for 2015 based on Race")
# Out:
# Text(0.5, 1.0, 'shootings for 2015 based on Race')

# %%
r_d_2016=d_2016['Person.Race'].value_counts()

# %%
r_d_2016.plot(kind="area", xlabel="Year", ylabel="Count", title="shootings for 2016 Based on Race", figsize=(6,6), color='cyan', grid="bool")
plt.xticks(rotation = 45)
plt.title("shootings for 2016 based on Race")
# Out:
# Text(0.5, 1.0, 'shootings for 2016 based on Race')

# %%
r_d_2017=d_2017['Person.Race'].value_counts()

# %%
r_d_2017.plot(kind="area", xlabel="Year", ylabel="Count", figsize=(6,6), color='cyan', grid="bool")
plt.xticks(rotation = 45)
plt.title("shootings for 2017 based on Race")
# Out:
# Text(0.5, 1.0, 'shootings for 2017 based on Race')

# %%
r_d_2018=d_2018['Person.Race'].value_counts()

# %%
r_d_2018.plot(kind="area", xlabel="Year", ylabel="Count", figsize=(6,6), color='cyan', grid="bool")
plt.xticks(rotation = 45)
plt.title("shootings for 2018 based on Race")
# Out:
# Text(0.5, 1.0, 'shootings for 2018 based on Race')

# %%
r_d_2019=d_2019['Person.Race'].value_counts()

# %%
r_d_2019.plot(kind="area", xlabel="Year", ylabel="Count", figsize=(6,6), color='cyan', grid="bool")
plt.xticks(rotation = 45)
plt.title("shootings for 2019 based on Race")
# Out:
# Text(0.5, 1.0, 'shootings for 2019 based on Race')

# %% [markdown]
# ##### Age

# %%
age_d_15=d_2015['Person.Age'].value_counts()

# %%
age_d_15.plot(kind="bar", xlabel="Year", ylabel="Count", title="shootings for 2015 based on Age", figsize=(16,6), color='orchid', grid="bool")
# Out:
# <AxesSubplot:title={'center':'shootings for 2015 based on Age'}, xlabel='Year', ylabel='Count'>

# %%
age_d_16=d_2016['Person.Age'].value_counts()

# %%
age_d_16.plot(kind="bar", xlabel="Year", ylabel="Count", title="shootings for 2016 based on Age", figsize=(16,6), color='orchid', grid="bool")
# Out:
# <AxesSubplot:title={'center':'shootings for 2016 based on Age'}, xlabel='Year', ylabel='Count'>

# %%
age_d_17=d_2017['Person.Age'].value_counts()

# %%
age_d_17.plot(kind="bar", xlabel="Year", ylabel="Count", title="shootings for 2017 based on Age", figsize=(16,6), color='purple', grid="bool")
# Out:
# <AxesSubplot:title={'center':'shootings for 2017 based on Age'}, xlabel='Year', ylabel='Count'>

# %%
age_d_18=d_2018['Person.Age'].value_counts()

# %%
age_d_18.plot(kind="bar", xlabel="Year", ylabel="Count", title="shootings for 2018 based on Age", figsize=(16,6), color='orchid', grid="bool")
# Out:
# <AxesSubplot:title={'center':'shootings for 2018 based on Age'}, xlabel='Year', ylabel='Count'>

# %%
age_d_19=d_2019['Person.Age'].value_counts()

# %%
age_d_19.plot(kind="bar", xlabel="Year", ylabel="Count", title="shootings for 2019 based on Age", figsize=(16,6), color='#BCA7E8', grid="bool")
# Out:
# <AxesSubplot:title={'center':'shootings for 2019 based on Age'}, xlabel='Year', ylabel='Count'>

# %% [markdown]
# #  Gender

# %%
g_d_15=d_2015['Person.Gender'].value_counts()
g_d_15
# Out:
# Male      952
# Female     42
# Name: Person.Gender, dtype: int64

# %%
names = ['Male', 'Female']
# Create a pieplot
plt.pie(g_d_15,labels=names,autopct = '%1.1f%%')

# add a circle at the center to transform it in a donut chart
my_circle=plt.Circle( (0,0), 0.7, color='white')
p=plt.gcf()
plt.title('Gender Wise Analysis for 2015')
p.gca().add_artist(my_circle)

plt.show()

# %%
g_d_16=d_2016['Person.Gender'].value_counts()
g_d_16
# Out:
# Male      922
# Female     40
# Name: Person.Gender, dtype: int64

# %%
names = ['Male', 'Female']
# Create a pieplot
plt.pie(g_d_16,labels=names,autopct = '%1.1f%%')
plt.title('Gender Wise Analysis for 2016')
# add a circle at the center to transform it in a donut chart
my_circle=plt.Circle( (0,0), 0.7, color='white')
p=plt.gcf()
p.gca().add_artist(my_circle)

plt.show()

# %%
g_d_17=d_2017['Person.Gender'].value_counts()
g_d_17
# Out:
# Male       939
# Female      45
# Unknown      2
# Name: Person.Gender, dtype: int64

# %%
names = ['Male', 'Female', 'Unkown']
# Create a pieplot
plt.pie(g_d_17,labels=names,autopct = '%1.1f%%')

# add a circle at the center to transform it in a donut chart
my_circle=plt.Circle( (0,0), 0.7, color='white')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title('Gender Wise Analysis for 2017')
plt.show()

# %%
g_d_18=d_2018['Person.Gender'].value_counts()
g_d_18
# Out:
# Male       939
# Female      52
# Unknown      1
# Name: Person.Gender, dtype: int64

# %%
names = ['Male', 'Female', 'Unkown']
# Create a pieplot
plt.pie(g_d_18,labels=names,autopct = '%1.1f%%')

# add a circle at the center to transform it in a donut chart
my_circle=plt.Circle( (0,0), 0.7, color='white')
p=plt.gcf()
plt.title('Gender Wise Analysis for 2018')
p.gca().add_artist(my_circle)

plt.show()

# %%
g_d_19=d_2019['Person.Gender'].value_counts()
g_d_19
# Out:
# Male       337
# Female      21
# Unknown      2
# Name: Person.Gender, dtype: int64

# %%
names = ['Male', 'Female', 'Unkown']
# Create a pieplot
plt.pie(g_d_19,labels=names,autopct = '%1.1f%%')

# add a circle at the center to transform it in a donut chart
my_circle=plt.Circle( (0,0), 0.7, color='white')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title('Gender Wise Analysis for 2019')
plt.show()

# %% [markdown]
# ## Location

# %%
s_d_15=d_2015['State'].value_counts()

# %%
s_d_15.plot(kind="bar", xlabel="Year", ylabel="Count",  figsize=(16,6), color='teal', grid="bool")
plt.xticks(rotation = 45)
plt.title("shootings per State for 2015")
# Out:
# Text(0.5, 1.0, 'shootings per State for 2015')

# %%
s_d_16=d_2016['State'].value_counts()

# %%
s_d_16.plot(kind="bar", xlabel="Year", ylabel="Count",  figsize=(16,6), color='teal', grid="bool")
plt.xticks(rotation = 45)
plt.title("shootings per State for 2016")
# Out:
# Text(0.5, 1.0, 'shootings per State for 2016')

# %%
s_d_17=d_2015['State'].value_counts()

# %%
s_d_17.plot(kind="bar", xlabel="Year", ylabel="Count",  figsize=(16,6), color='teal', grid="bool")
plt.xticks(rotation = 45)
plt.title("shootings per State for 2017")
# Out:
# Text(0.5, 1.0, 'shootings per State for 2017')

# %%
s_d_18=d_2018['State'].value_counts()

# %%
s_d_18.plot(kind="bar", xlabel="Year", ylabel="Count",  figsize=(16,6), color='teal', grid="bool")
plt.xticks(rotation = 45)
plt.title("shootings per State for 2018")
# Out:
# Text(0.5, 1.0, 'shootings per State for 2018')

# %%
s_d_19=d_2019['State'].value_counts()

# %%
s_d_19.plot(kind="bar", xlabel="Year", ylabel="Count",  figsize=(16,6), color='teal', grid="bool")
plt.xticks(rotation = 45)
plt.title("shootings per State for 2019")
# Out:
# Text(0.5, 1.0, 'shootings per State for 2019')

# %% [markdown]
# ## Threat_Levels

# %%
t_d_15=d_2015['Factors.Threat-Level'].value_counts()

# %%
t_d_15.plot(kind="bar", xlabel="ThreatLevel", ylabel="Count", title="ThreatLevel for 2015", figsize=(12,6), color='#808080', grid="bool")
# Out:
# <AxesSubplot:title={'center':'ThreatLevel for 2015'}, xlabel='ThreatLevel', ylabel='Count'>

# %%
t_d_16=d_2016['Factors.Threat-Level'].value_counts()

# %%
t_d_16.plot(kind="bar", xlabel="ThreatLevel", ylabel="Count", title="ThreatLevel for 2016", figsize=(12,6), color='#808080', grid="bool")
# Out:
# <AxesSubplot:title={'center':'ThreatLevel for 2016'}, xlabel='ThreatLevel', ylabel='Count'>

# %%
t_d_17=d_2017['Factors.Threat-Level'].value_counts()

# %%
t_d_17.plot(kind="bar", xlabel="ThreatLevel", ylabel="Count", title="ThreatLevel for 2017", figsize=(12,6), color='#808080', grid="bool")
# Out:
# <AxesSubplot:title={'center':'ThreatLevel for 2017'}, xlabel='ThreatLevel', ylabel='Count'>

# %%
t_d_18=d_2018['Factors.Threat-Level'].value_counts()

# %%
t_d_18.plot(kind="bar", xlabel="ThreatLevel", ylabel="Count", title="ThreatLevel  for 2018", figsize=(12,6), color='#808080', grid="bool")
# Out:
# <AxesSubplot:title={'center':'ThreatLevel  for 2018'}, xlabel='ThreatLevel', ylabel='Count'>

# %%
t_d_19=d_2019['Factors.Threat-Level'].value_counts()

# %%
t_d_19.plot(kind="bar", xlabel="ThreatLevel", ylabel="Count", title="ThreatLevel  for 2019", figsize=(12,6), color='#808080', grid="bool")
# Out:
# <AxesSubplot:title={'center':'ThreatLevel  for 2019'}, xlabel='ThreatLevel', ylabel='Count'>

# %% [markdown]
# ## Shoot Manner

# %%
m_d_15=d_2015['Shooting.Manner'].value_counts()
m_d_15
# Out:
# shot                926
# shot and Tasered     68
# Name: Shooting.Manner, dtype: int64

# %%
m_d_15.plot(kind="bar", xlabel="Shooting Manner", ylabel="Count", title="Shooting Manner for 2015", figsize=(12,6), grid="bool",color="#ff4500")
# Out:
# <AxesSubplot:title={'center':'Shooting Manner for 2015'}, xlabel='Shooting Manner', ylabel='Count'>

# %%
m_d_16=d_2016['Shooting.Manner'].value_counts()
m_d_16
# Out:
# shot                900
# shot and Tasered     62
# Name: Shooting.Manner, dtype: int64

# %%
m_d_16.plot(kind="bar", xlabel="Shooting Manner", ylabel="Count", title="Shooting Manner for 2016", figsize=(12,6), grid="bool",color="#ff8243")
# Out:
# <AxesSubplot:title={'center':'Shooting Manner for 2016'}, xlabel='Shooting Manner', ylabel='Count'>

# %%
m_d_17=d_2017['Shooting.Manner'].value_counts()
m_d_17
# Out:
# shot                935
# shot and Tasered     51
# Name: Shooting.Manner, dtype: int64

# %%
m_d_17.plot(kind="bar", xlabel="Shooting Manner", ylabel="Count", title="Shooting Manner for 2017", figsize=(12,6), grid="bool",color="#e25822")
# Out:
# <AxesSubplot:title={'center':'Shooting Manner for 2017'}, xlabel='Shooting Manner', ylabel='Count'>

# %%
m_d_18=d_2018['Shooting.Manner'].value_counts()
m_d_18
# Out:
# shot                962
# shot and Tasered     30
# Name: Shooting.Manner, dtype: int64

# %%
m_d_18.plot(kind="bar", xlabel="Shooting Manner", ylabel="Count", title="Shooting Manner for 2018", figsize=(12,6), grid="bool",color="#ff6700")
# Out:
# <AxesSubplot:title={'center':'Shooting Manner for 2018'}, xlabel='Shooting Manner', ylabel='Count'>

# %%
m_d_19=d_2019['Shooting.Manner'].value_counts()
m_d_19
# Out:
# shot                346
# shot and Tasered     14
# Name: Shooting.Manner, dtype: int64

# %%
m_d_19.plot(kind="bar", xlabel="Shooting Manner", ylabel="Count", title="Shooting Manner for 2019", figsize=(12,6), grid="bool",color="#ec5800")
# Out:
# <AxesSubplot:title={'center':'Shooting Manner for 2019'}, xlabel='Shooting Manner', ylabel='Count'>

# %% [markdown]
# # Month Wise Analysis

# %%
m_d_19=d_2019['Incident.Date.Month'].value_counts()
m_d_19
# Out:
# 1    95
# 3    88
# 2    72
# 4    66
# 5    39
# Name: Incident.Date.Month, dtype: int64

# %%
m_d_19.plot(kind="bar", xlabel="Months", ylabel="Count", title="Shootings base on months for 2019", figsize=(12,6), grid="bool")
# Out:
# <AxesSubplot:title={'center':'Shootings base on months for 2019'}, xlabel='Months', ylabel='Count'>

# %%
m_d_18=d_2018['Incident.Date.Month'].value_counts()
m_d_18
# Out:
# 3     110
# 1      99
# 4      98
# 7      89
# 5      83
# 6      81
# 2      80
# 11     77
# 10     75
# 8      74
# 12     71
# 9      55
# Name: Incident.Date.Month, dtype: int64

# %%
m_d_18.plot(kind="bar", xlabel="Months", ylabel="Count", title="Shootings base on months for 2018", figsize=(12,6), grid="bool")
# Out:
# <AxesSubplot:title={'center':'Shootings base on months for 2018'}, xlabel='Months', ylabel='Count'>

# %%
m_d_17=d_2017['Incident.Date.Month'].value_counts()
m_d_17
# Out:
# 2     100
# 7      94
# 1      92
# 10     85
# 11     84
# 6      84
# 8      82
# 12     78
# 3      76
# 5      74
# 9      70
# 4      67
# Name: Incident.Date.Month, dtype: int64

# %%
m_d_17.plot(kind="bar", xlabel="Months", ylabel="Count", title="Shootings base on months for 2017", figsize=(12,6), grid="bool")
# Out:
# <AxesSubplot:title={'center':'Shootings base on months for 2017'}, xlabel='Months', ylabel='Count'>

# %%
m_d_16=d_2016['Incident.Date.Month'].value_counts()
m_d_16
# Out:
# 6     92
# 3     92
# 2     86
# 8     82
# 1     81
# 12    78
# 9     78
# 11    77
# 10    77
# 5     74
# 4     73
# 7     72
# Name: Incident.Date.Month, dtype: int64

# %%
m_d_16.plot(kind="bar", xlabel="Months", ylabel="Count", title="Shootings base on months for 2016", figsize=(12,6), grid="bool")
# Out:
# <AxesSubplot:title={'center':'Shootings base on months for 2016'}, xlabel='Months', ylabel='Count'>

# %%
m_d_15=d_2015['Incident.Date.Month'].value_counts()
m_d_15
# Out:
# 7     104
# 8      94
# 3      92
# 12     88
# 10     84
# 4      84
# 9      82
# 11     77
# 2      77
# 1      76
# 5      71
# 6      65
# Name: Incident.Date.Month, dtype: int64

# %%
m_d_15.plot(kind="bar", xlabel="Months", ylabel="Count", title="Shootings base on months for 2015", figsize=(12,6), grid="bool")
# Out:
# <AxesSubplot:title={'center':'Shootings base on months for 2015'}, xlabel='Months', ylabel='Count'>
